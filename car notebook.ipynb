# %%
import pandas as pd
import numpy as np

# %%
car = pd.read_csv('cardekho_dataset.csv')

# %%
car.head()
# Out:
#    Unnamed: 0       car_name    brand     model  vehicle_age  km_driven  \
# 0           0    Maruti Alto   Maruti      Alto            9     120000
# 1           1  Hyundai Grand  Hyundai     Grand            5      20000
# 2           2    Hyundai i20  Hyundai       i20           11      60000
# 3           3    Maruti Alto   Maruti      Alto            9      37000
# 4           4  Ford Ecosport     Ford  Ecosport            6      30000
#
#   fuel_type transmission_type  mileage  selling_price
# 0    Petrol            Manual    19.70         120000
# 1    Petrol            Manual    18.90         550000
# 2    Petrol            Manual    17.00         215000
# 3    Petrol            Manual    20.92         226000
# 4    Diesel            Manual    22.77         570000

# %%
car.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 car.shape()
#
# TypeError: 'tuple' object is not callable

# %%
car.shape
# Out:
# (15411, 9)

# %%
car.info
# Out:
# <bound method DataFrame.info of        sr. no     brand     model  vehicle_age  km_driven fuel_type  \
# 0           0    Maruti      Alto            9     120000    Petrol
# 1           1   Hyundai     Grand            5      20000    Petrol
# 2           2   Hyundai       i20           11      60000    Petrol
# 3           3    Maruti      Alto            9      37000    Petrol
# 4           4      Ford  Ecosport            6      30000    Diesel
# ...       ...       ...       ...          ...        ...       ...
# 15406   19537   Hyundai       i10            9      10723    Petrol
# 15407   19540    Maruti    Ertiga            2      18000    Petrol
# 15408   19541     Skoda     Rapid            6      67000    Diesel
# 15409   19542  Mahindra    XUV500            5    3800000    Diesel
# 15410   19543     Honda      City            2      13000    Petrol
#
#       transmission_type  mileage  selling_price
# 0                Manual    19.70         120000
# ...

# %%
    car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sr. no             15411 non-null  int64
#  1   brand              15411 non-null  object
#  2   model              15411 non-null  object
#  3   vehicle_age        15411 non-null  int64
#  4   km_driven          15411 non-null  int64
#  5   fuel_type          15411 non-null  object
#  6   transmission_type  15411 non-null  object
#  7   mileage            15411 non-null  float64
#  8   selling_price      15411 non-null  int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 1.1+ MB

# %%
car['year'] = unique
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 car['year'] = unique
#
# NameError: name 'unique' is not defined

# %%
car['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG', 'LPG', 'Electric'], dtype=object)

# %%
car['vehicle_age'].unique()
# Out:
# array([ 9,  5, 11,  6,  8,  3,  2,  4,  7, 10, 14, 12,  1, 15, 13, 16, 17,
#        18, 29, 19,  0, 21, 22, 25], dtype=int64)

# %%
backup = car.copy()

# %%
car['vehicle_age'] = 2023-car['vehicle_age']

# %%
car['vehicle_age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 15411 entries, 0 to 15410
# Series name: vehicle_age
# Non-Null Count  Dtype
# --------------  -----
# 15411 non-null  int64
# dtypes: int64(1)
# memory usage: 120.5 KB

# %%
car['vehicle_age'].unique()
# Out:
# array([2014, 2018, 2012, 2017, 2015, 2020, 2021, 2019, 2016, 2013, 2009,
#        2011, 2022, 2008, 2010, 2007, 2006, 2005, 1994, 2004, 2023, 2002,
#        2001, 1998], dtype=int64)

# %%
car.describe()
# Out:
#          Unnamed: 0   vehicle_age     km_driven       mileage  selling_price
# count  15411.000000  15411.000000  1.541100e+04  15411.000000   1.541100e+04
# mean    9811.857699   2016.963662  5.561648e+04     19.701151   7.749711e+05
# std     5643.418542      3.013291  5.161855e+04      4.171265   8.941284e+05
# min        0.000000   1994.000000  1.000000e+02      4.000000   4.000000e+04
# 25%     4906.500000   2015.000000  3.000000e+04     17.000000   3.850000e+05
# 50%     9872.000000   2017.000000  5.000000e+04     19.670000   5.560000e+05
# 75%    14668.500000   2019.000000  7.000000e+04     22.700000   8.250000e+05
# max    19543.000000   2023.000000  3.800000e+06     33.540000   3.950000e+07

# %%
car.drop(columns=['Unnamed: 0'], inplace=True)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car_name           15411 non-null  object
#  1   brand              15411 non-null  object
#  2   model              15411 non-null  object
#  3   vehicle_age        15411 non-null  int64
#  4   km_driven          15411 non-null  int64
#  5   fuel_type          15411 non-null  object
#  6   transmission_type  15411 non-null  object
#  7   mileage            15411 non-null  float64
#  8   selling_price      15411 non-null  int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 1.1+ MB

# %%
car.drop(car[car['selling_price'] > 6000000].index, inplace=True)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15346 entries, 0 to 15410
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car_name           15346 non-null  object
#  1   brand              15346 non-null  object
#  2   model              15346 non-null  object
#  3   vehicle_age        15346 non-null  int64
#  4   km_driven          15346 non-null  int64
#  5   fuel_type          15346 non-null  object
#  6   transmission_type  15346 non-null  object
#  7   mileage            15346 non-null  float64
#  8   selling_price      15346 non-null  int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 1.2+ MB

# %%
car.to_csv('cleaned_car.csv')

# %%
cols_drop = ['selling_price','fuel_type']
x=car.drop(columns=cols_drop)
y=car['selling_price']

# %%
x
# Out:
#               car_name     brand     model  vehicle_age  km_driven  \
# 0          Maruti Alto    Maruti      Alto         2014     120000
# 1        Hyundai Grand   Hyundai     Grand         2018      20000
# 2          Hyundai i20   Hyundai       i20         2012      60000
# 3          Maruti Alto    Maruti      Alto         2014      37000
# 4        Ford Ecosport      Ford  Ecosport         2017      30000
# ...                ...       ...       ...          ...        ...
# 15406      Hyundai i10   Hyundai       i10         2014      10723
# 15407    Maruti Ertiga    Maruti    Ertiga         2021      18000
# 15408      Skoda Rapid     Skoda     Rapid         2017      67000
# 15409  Mahindra XUV500  Mahindra    XUV500         2018    3800000
# 15410       Honda City     Honda      City         2021      13000
#
#       transmission_type  mileage
# 0                Manual    19.70
# 1                Manual    18.90
# 2                Manual    17.00
# ...

# %%
y
# Out:
# 0         120000
# 1         550000
# 2         215000
# 3         226000
# 4         570000
#           ...
# 15406     250000
# 15407     925000
# 15408     425000
# 15409    1225000
# 15410    1200000
# Name: selling_price, Length: 15346, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder

# %%
ohe = OneHotEncoder()

# %%
ohe.fit(x[['brand','model']])
# Out:
# OneHotEncoder()

# %%
ohe = OneHotEncoder()
ohe.fit(x[['brand','model']])
# Out:
# OneHotEncoder()

# %%
ohe.fit(x)
# Out:
# OneHotEncoder()

# %%
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
categorical_columns = ['car_name','brand', 'model', 'transmission_type']  # Adjust column names as per your data

column_trans = make_column_transformer(
    (OneHotEncoder(handle_unknown='ignore'), categorical_columns),  # One-hot encode categorical columns
    remainder='passthrough'
)

# %%
lr = LinearRegression()

# %%
pipe = make_pipeline(column_trans,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['car_name', 'brand', 'model',
#                                                    'transmission_type'])])),
#                 ('linearregression', LinearRegression())])

# %%
y_pred = pipe.predict(x_test)

# %%
scores=[]
for i in range(1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(x_train,y_train)
    y_pred=pipe.predict(x_test)
    scores.append(r2_score(y_test,y_pred))

# %%
np.argmax(scores)
# Out:
# 322

# %%
scores[np.argmax(scores)]
# Out:
# 0.6820746502731392

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15411 entries, 0 to 15410
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   car_name           15411 non-null  object
#  1   brand              15411 non-null  object
#  2   model              15411 non-null  object
#  3   vehicle_age        15411 non-null  int64
#  4   km_driven          15411 non-null  int64
#  5   fuel_type          15411 non-null  object
#  6   transmission_type  15411 non-null  object
#  7   mileage            15411 non-null  float64
#  8   selling_price      15411 non-null  int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 1.1+ MB

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearRegressionModel.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['maruti','alto','2014','12000','petrol','manual','19.70']], columns =['brand','model','vehicle_age','km_driven','fuel_type','transmission_type','mileage']))
# Out:
# array([834914.09499148])

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
x_encoded = pd.get_dummies(x, columns=['car_name','brand', 'model', 'transmission_type'], drop_first=True)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_encoded, y, test_size=0.2, random_state=42)

# %%
rf_model = RandomForestRegressor(n_estimators=100, random_state=42)  # Example hyperparameters

# %%
rf_model.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = rf_model.predict(x_test)

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.934851940141106

# %%
pickle.dump(pipe,open('RandomForestRegression.pkl','wb'))

# %%
pipe.predict(pd.DataFrame([['Maruti Alto','maruti','alto','2014','12000','petrol','manual','19.70']], columns =['car_name','brand','model','vehicle_age','km_driven','fuel_type','transmission_type','mileage']))
# Out:
# array([821353.61525282])

# %%
import sklearn


from sklearn.metrics import classification_report

from sklearn.datasets import load_breast_cancer

from sklearn.ensemble import GradientBoostingClassifier

# %%
x,y = car.drop('y',axis=1),car.y

test_size = 0.30 # taking 70:30 training and test set

seed = 7 # Random number seeding for repeatability of the code

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size, random_state=seed)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 x,y = car.drop('y',axis=1),car.y
#       3 test_size = 0.30 # taking 70:30 training and test set
#       5 seed = 7 # Random number seeding for repeatability of the code
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:5568, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5420 def drop(
#    5421     self,
#    5422     labels: IndexLabel | None = None,
#    (...)
#    5429     errors: IgnoreRaise = "raise",
#    5430 ) -> DataFrame | None:
#    5431     """
#    5432     Drop specified labels from rows or columns.
#    5433
#    (...)
#    5566             weight  1.0     0.8
#    5567     """
# -> 5568     return super().drop(
#    5569         labels=labels,
# ...
